# %% [markdown]
# # LLM4AD Tutorial -- Use LLM4AD to Solve TSP Problem

# %%
# !pip install llm4ad

# %% [markdown]
# ## Installation
# 1. Create a Python environment with Python 3.9-3.11.
#     ```shell
#     conda create -n llm4ad310 python=3.10
#     ```
# 2. Activate the `llm4ad310` environment.
#     ```shell
#     conda activate llm4ad310
#     ```
# 3. Install `llm4ad` and other required packages used in this tutorial.
#     ```shell
#     pip install llm4ad torch tensorboard jupyter notebook
#     ```

# %% [markdown]
# ## Step 1: Template program
# We need to create a **template program** for an algorithm that includes the following:
# 1) All the **Python packages** required for designing the algorithm.
# 2) The **names of the functions**, their **arguments**, and the **type hints** of their return values.
# 3) **Descriptive information** for each argument provided in the function’s docstring.
# 4) A **simple implementation** for the function (for the `EoH` algorithm, you don’t have to include a full implementation—a simple pass statement with a return is fine).
#
# This template program serves as a "boilerplate" for the search methods. The parameter descriptions in the docstring can also help an LLM better understand the algorithm’s purpose, which can reduce errors during the search process.

# %% [markdown]
# Please note that the destination node is also added to the arguments list to provide more information.

# %%
template_program = '''
import numpy as np

def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int: 
    """Design an algorithm to select the next node in each step.
    Args:
        current_node    : ID of the current node.
        destination_node: ID of the destination node.
        unvisited_nodes : Array of IDs of unvisited nodes.
        distance_matrix : Distance matrix of nodes.
    Return:
        ID of the next node to visit.
    """
    next_node = unvisited_nodes[0]
    return next_node
'''

# %% [markdown]
# ## Step 2: Evaluation interface
# We should provide an evaluator for LLM4AD that outputs a score for an algorithm, which is higher the better. And always return `None` if the result is illegal.

# %% [markdown]
# For the convenience, we have provided functions to produce datasets and calculate the distance for an algorithm. The usages for these functions are shown below.
# - Import `GetData` to get TSP instances.
# - Import `cal_avg_distance` for score calculation.

# %%
from evaluation import cal_avg_distance
from get_instance import GetData

import numpy as np

def select_next_node(current_node: int, destination_node: int, 
                     unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int: 
    next_node = unvisited_nodes[0]  # visit the first node in unvisited list
    return next_node

data = GetData(n_instance=1, n_cities=50).generate_instances()  # we create one TSP instance, the instance has 50 cities
distance = cal_avg_distance(instance_data=data, n_instance=1, n_cities=50, evaluated_algorithm=select_next_node)
print(f'distance: {distance}')

# %%
from evaluation import cal_avg_distance
from get_instance import GetData

import numpy as np

def select_next_node(current_node: int, destination_node: int, 
                     unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int: 
    next_node = unvisited_nodes[-1]  # visit the last node in unvisited list
    return next_node

data = GetData(n_instance=1, n_cities=50).generate_instances()  # we create one TSP instance, the instance has 50 cities
distance = cal_avg_distance(instance_data=data, n_instance=1, n_cities=50, evaluated_algorithm=select_next_node)
print(f'distance: {distance}')

# %% [markdown]
# In LLM4AD platform, we should complete following steps:
# 1. Extend the `llm4ad.base.evaluate.Evaluation` class.
# 2. Passing evaluate arguments to the super class if necessary.
#     - Passing the `template_program` to the super class. The `template_program` here acts as a biolerplate for all evaluated algorithms.
#     - Passing the `task_description` parameter to the super class to
#     - If `use_numba_accelerate` is set to `True`, the numba wrapper will be added to the evaluated algorithm automatically. It should be noted that the acceleration provided by numba is not promising in all cases.
#     - Set a `timeout_seconds` to restrict the maximum evaluation time of an algorithm. If the evaluation violate the time restriction, the evaluation process will be terminated automatically and the score of the evaluated algorihtm will be set to `None`.
# 3. override the `evaluate_program` function and return the score of the evaluated algorithm.
#     - The `program_str` argument is the string type of the algorithm to be evaluated. The string is provided for the requirements for penalizing the length of the algorithm code, or compile the program in an alternative way.
#     - The `callable_func` is the compiled version for the evlauted algorithm. It is callable and thus can be directly used for evaluation.
#
# In our TSP task, we invoke `avg_dist` function to get the average distance over all TSP instances (test cases). **Please note that the distance has been inverted. As the distance is used as the score of an algorithm, which is higher the better.**

# %%
from llm4ad.base import LLM, Evaluation, SecureEvaluator
from evaluation import cal_avg_distance
from get_instance import GetData


class TSPEval(Evaluation):
    """Evaluator for traveling salesman problem."""

    def __init__(self):
        super().__init__(
            template_program=template_program, 
            task_description='',
            use_numba_accelerate=False,
            timeout_seconds=20
        )
        getData = GetData(n_instance=16, n_cities=50)
        self._datasets = getData.generate_instances()

    def evaluate_program(self, program_str: str, callable_func: callable):
        dist = cal_avg_distance(self._datasets, 16, 50, callable_func)
        return -dist

# %% [markdown]
# **Tips:** Here is a tip for debugging: We first create an evaluator and evaluate the `template_program` in debug mode.

# %%
tsp_eval = TSPEval()
evaluator = SecureEvaluator(tsp_eval, debug_mode=True)
score, time = evaluator.evaluate_program_record_time(template_program)
print(f'score: {score} eval time: {time}')

# %% [markdown]
# ## Step 3: LLM interface
# The LLM interface defines how we access to the LLM. The following cell shows an example for using an HTTPS API to query remote LLMs.
#
# **Tips:** Invoke `draw_sample` function to test the accessibility.

# %%
from llm4ad.tools.llm.llm_api_https import HttpsApi

llm = HttpsApi(
    host='api.bltcy.ai',
    key='sk-dHvAGxNBt11jP9QqdOJse7YjA59h5BHTSS2zWaJZT9e2Ltws',
    model='gpt-4o-mini'
)

response = llm.draw_sample('Hello!')
response
# Out:
# 'Hi there! Nice to meet you. How can I help today?\n\nI can assist with:\n- Explaining concepts or answering questions\n- Writing and editing (emails, essays, resumes, etc.)\n- Coding and debugging\n- Math, science, or homework help\n- Brainstorming ideas or planning (projects, trips, events)\n- Translation or summarization\n- General chat or guidance\n\nTell me what you’re aiming for or drop a question, and I’ll tailor my help.'

# %% [markdown]
# ## Step 4: Automated algorithm design
# Install following packages since we will show the usage of tensorboard profiler later.

# %%
# !pip install numpy==1.26.0
# !pip install torch
# !pip install tensorboard
# !pip install tensorboardX
# !rm -rf TSP

# %% [markdown]
# 1. Create a profiler (for recording and visualizing the results).
# 2. Initialize a search method.
# 3. Run.
#
# You can visualize the results through tensorboard:
# ```shell
# tensorboard --logdir TSP --port 6006
# ```
# And the results will be demonstrated in http://127.0.0.1:6006.

# %%
from llm4ad.tools.profiler import TensorboardProfiler
from llm4ad.method.eoh import EoH

profiler = TensorboardProfiler(log_dir='TSP')

eoh = EoH(llm=llm, 
          evaluation=tsp_eval, 
          profiler=profiler, 
          max_sample_nums=20,
          num_samplers=1, 
          num_evaluators=1)

eoh.run()
# Out:
# ====================================================================
# LLM Parameters
# --------------------------------------------------------------------
#   - LLM: HttpsApi
#   - do_auto_trim: True
#   - debug_mode: False
#   - _host: api.bltcy.ai
#   - _key: sk-dHvAGxNBt11jP9QqdOJse7YjA59h5BHTSS2zWaJZT9e2Ltws
#   - _model: gpt-5-nano
#   - _timeout: 60
#   - _kwargs: {}
#   - _cumulative_error: 0
# ====================================================================
# Problem Parameters
# --------------------------------------------------------------------
#   - Problem: TSPEval
#   - task_description:
#   - use_numba_accelerate: False
#   - use_protected_div: False
#   - protected_div_delta: 1e-05
#   - random_seed: None
#   - timeout_seconds: 20
#   - exec_code: True
#   - safe_evaluate: True
#   - daemon_eval_process: False
#   - fork_proc: auto
# ====================================================================
# Method Parameters
# --------------------------------------------------------------------
#   - Method: EoH
#   - _max_generations: 10
#   - _max_sample_nums: 20
#   - _pop_size: 5
#   - _selection_num: 2
#   - _use_e2_operator: True
#   - _use_m1_operator: True
#   - _use_m2_operator: True
#   - _num_samplers: 1
#   - _num_evaluators: 1
#   - _resume_mode: False
#   - _debug_mode: False
#   - _multi_thread_or_process_eval: thread
#   - _function_to_evolve_name: select_next_node
#   - _tot_sample_nums: 0
#   - _initial_sample_nums_max: 10
#   - _evaluation_executor: <concurrent.futures.thread.ThreadPoolExecutor object at 0x309a03710>
# =====================================================================
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     # Ensure we are working with integers
#     unvisited = unvisited_nodes.astype(int)
#
#     d_from_current = distance_matrix[current_node, unvisited]
#     d_to_destination = distance_matrix[unvisited, destination_node]
#     score = d_from_current + d_to_destination
#
#     next_index = int(np.argmin(score))
#     return int(unvisited[next_index])
# ------------------------------------------------------
# Score        : -8.060258218042321
# Sample time  : 11.887616872787476
# Evaluate time: 0.039895057678222656
# Sample orders: 1
# ------------------------------------------------------
# Current best score: -8.060258218042321
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     import numpy as np
#
#     # If there are no unvisited nodes left, go directly to the destination
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes
#     # Distances from current node to each unvisited node
#     to_unvisited = distance_matrix[current_node, unvisited]
#     # Distances from each unvisited node to the destination
#     unvisited_to_dest = distance_matrix[unvisited, destination_node]
#     # Score = distance to candidate + distance from candidate to destination
#     scores = to_unvisited + unvisited_to_dest
#
#     next_idx = int(np.argmin(scores))
#     return int(unvisited[next_idx])
# ------------------------------------------------------
# Score        : -8.060258218042321
# Sample time  : 18.447407960891724
# Evaluate time: 0.033750057220458984
# Sample orders: 2
# ------------------------------------------------------
# Current best score: -8.060258218042321
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return -1
#
#     best_node = int(unvisited_nodes[0])
#     best_cost = float('inf')
#
#     current = int(current_node)
#     dest = int(destination_node)
#
#     for idx in range(unvisited_nodes.size):
#         cand = int(unvisited_nodes[idx])
#         cost_to_cand = distance_matrix[current, cand]
#         cost_cand_to_dest = distance_matrix[cand, dest]
#         total_cost = cost_to_cand + cost_cand_to_dest
#         if total_cost < best_cost:
#             best_cost = total_cost
#             best_node = cand
#
#     return best_node
# ------------------------------------------------------
# Score        : -8.060258218042321
# Sample time  : 16.164026975631714
# Evaluate time: 0.03985190391540527
# Sample orders: 3
# ------------------------------------------------------
# Current best score: -8.060258218042321
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     import numpy as np
#     unvisited = np.asarray(unvisited_nodes)
#     if unvisited.size == 0:
#         return int(destination_node)
#     current = int(current_node)
#     dest = int(destination_node)
#
#     scores = distance_matrix[current, unvisited] + distance_matrix[unvisited, dest]
#     best_index = int(np.argmin(scores))
#     return int(unvisited[best_index])
# ------------------------------------------------------
# Score        : -8.060258218042321
# Sample time  : 14.218142986297607
# Evaluate time: 0.04169607162475586
# Sample orders: 4
# ------------------------------------------------------
# Current best score: -8.060258218042321
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     if unvisited_nodes.size == 1:
#         only = int(unvisited_nodes[0])
#         if only == destination_node:
#             return only
#
#     candidates = unvisited_nodes
#     if np.any(candidates == destination_node) and candidates.size > 1:
#         candidates = candidates[candidates != destination_node]
#
#     if candidates.size == 0:
#         return int(destination_node)
#
#     current = int(current_node)
#     dest = int(destination_node)
#
#     scores = []
#     for cand in candidates:
#         cand_int = int(cand)
#         d1 = distance_matrix[current, cand_int]
#         d2 = distance_matrix[cand_int, dest]
#         if np.isnan(d1) or np.isnan(d2):
#             score = np.inf
#         else:
#             score = float(d1 + d2)
#         scores.append(score)
#
#     scores = np.asarray(scores)
#     min_idx = int(np.argmin(scores))
#     return int(candidates[min_idx])
# ------------------------------------------------------
# Score        : -8.060258218042321
# Sample time  : 19.276442766189575
# Evaluate time: 0.05747103691101074
# Sample orders: 5
# ------------------------------------------------------
# Current best score: -8.060258218042321
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     # Ensure we are working with integers
#     unvisited = unvisited_nodes.astype(int)
#
#     # Distances from current to unvisited and from unvisited to destination
#     d_from_current = distance_matrix[current_node, unvisited]
#     d_to_destination = distance_matrix[unvisited, destination_node]
#
#     # Distance from current to destination
#     d_cur_to_dest = distance_matrix[current_node, destination_node]
#
#     # Check which unvisited nodes lie on a shortest path from current to destination
#     on_path_mask = np.isclose(d_from_current + d_to_destination, d_cur_to_dest)
#
#     if np.any(on_path_mask):
#         candidates_on_path = unvisited[on_path_mask]
#         d_from_current_on_path = distance_matrix[current_node, candidates_on_path]
#         next_index = int(np.argmin(d_from_current_on_path))
#         return int(candidates_on_path[next_index])
#
#     # Fallback: pick the unvisited node closest to the destination
#     next_index = int(np.argmin(d_to_destination))
#     return int(unvisited[next_index])
# ------------------------------------------------------
# Score        : -18.87846365675391
# Sample time  : 18.06716299057007
# Evaluate time: 0.05037403106689453
# Sample orders: 6
# ------------------------------------------------------
# Current best score: -8.060258218042321
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     # Ensure we are working with integers
#     unvisited = unvisited_nodes.astype(int)
#
#     d_from_current = distance_matrix[current_node, unvisited]
#
#     # Lookahead: for each candidate, minimal distance to destination via any intermediate node
#     cand_to_all = distance_matrix[unvisited, :]
#     all_to_dest = distance_matrix[:, destination_node]
#     lookahead = np.min(cand_to_all + all_to_dest[np.newaxis, :], axis=1)
#
#     score = d_from_current + lookahead
#
#     next_index = int(np.argmin(score))
#     return int(unvisited[next_index])
# ------------------------------------------------------
# Score        : -8.060258218042321
# Sample time  : 19.99393939971924
# Evaluate time: 0.04415726661682129
# Sample orders: 7
# ------------------------------------------------------
# Current best score: -8.060258218042321
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     ALPHA = 0.6  # Tunable parameter balancing local vs. goal guidance
#
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     # Ensure we are working with integers
#     unvisited = unvisited_nodes.astype(int)
#
#     d_from_current = distance_matrix[current_node, unvisited]
#     d_to_destination = distance_matrix[unvisited, destination_node]
#     score = ALPHA * d_from_current + (1 - ALPHA) * d_to_destination
#
#     next_index = int(np.argmin(score))
#     return int(unvisited[next_index])
# ------------------------------------------------------
# Score        : -7.6266697669819
# Sample time  : 14.950708866119385
# Evaluate time: 0.04154610633850098
# Sample orders: 8
# ------------------------------------------------------
# Current best score: -7.6266697669819
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#     rng = np.random.default_rng(0)  # deterministic for reproducibility
#
#     best_candidate = None
#     best_avg_total = float('inf')
#     num_rollouts = 10  # number of random playouts per candidate
#
#     for cand in unvisited:
#         cand = int(cand)
#         remaining = unvisited[unvisited != cand]
#
#         if remaining.size == 0:
#             # Only this candidate remains
#             total_dist = distance_matrix[current_node, cand] + distance_matrix[cand, destination_node]
#             avg_dist = total_dist
#         else:
#             total_dist_sum = 0.0
#             for _ in range(num_rollouts):
#                 perm = rng.permutation(remaining)
#                 dist = distance_matrix[current_node, cand]
#                 cur = cand
#                 for nxt in perm:
#                     dist += distance_matrix[cur, int(nxt)]
#                     cur = int(nxt)
#                 dist += distance_matrix[cur, destination_node]
#                 total_dist_sum += dist
#             avg_dist = total_dist_sum / float(num_rollouts)
#
#         if avg_dist < best_avg_total:
#             best_avg_total = avg_dist
#             best_candidate = cand
#
#     return int(best_candidate)
# ------------------------------------------------------
# Score        : -12.570038451549099
# Sample time  : 19.296711206436157
# Evaluate time: 0.9143130779266357
# Sample orders: 9
# ------------------------------------------------------
# Current best score: -7.6266697669819
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#
#     # Submatrix for unvisited nodes
#     sub = distance_matrix[np.ix_(unvisited, unvisited)]
#     # Sum of distances from each candidate to all other unvisited nodes
#     sums = sub.sum(axis=1)
#
#     next_index = int(np.argmin(sums))
#     return int(unvisited[next_index])
# ------------------------------------------------------
# Score        : -30.986766219989573
# Sample time  : 22.832645893096924
# Evaluate time: 0.03103780746459961
# Sample orders: 10
# ------------------------------------------------------
# Current best score: -7.6266697669819
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#     best_candidate = None
#     best_total = float('inf')
#     depth_limit = 3  # fixed shallow playout depth
#
#     rng = np.random.default_rng(0)  # deterministic for reproducibility (kept for consistency)
#
#     for cand in unvisited:
#         cand = int(cand)
#         remaining = unvisited[unvisited != cand]
#
#         # Cost from current to candidate
#         dist_to_cand = distance_matrix[current_node, cand]
#
#         if remaining.size == 0:
#             total_dist = dist_to_cand + distance_matrix[cand, destination_node]
#         else:
#             # Shallow greedy playout: visit up to depth_limit nodes from 'remaining'
#             dist = dist_to_cand
#             cur = cand
#             rem = remaining.copy()
#             steps = min(depth_limit, rem.size)
#             for _ in range(steps):
#                 # choose the nearest neighbor among remaining
#                 dists = distance_matrix[cur, rem]
#                 idx = int(np.argmin(dists))
#                 nxt = int(rem[idx])
#                 dist += distance_matrix[cur, nxt]
#                 cur = nxt
#                 # remove chosen node from remaining
#                 rem = rem[np.delete(np.arange(rem.size), idx)]
#                 if rem.size == 0:
#                     break
#             dist += distance_matrix[cur, destination_node]
#             total_dist = dist
#
#         if total_dist < best_total:
#             best_total = total_dist
#             best_candidate = cand
#
#     return int(best_candidate)
# ------------------------------------------------------
# Score        : -8.610086511686402
# Sample time  : 13.983006954193115
# Evaluate time: 0.20893311500549316
# Sample orders: 11
# ------------------------------------------------------
# Current best score: -7.6266697669819
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     # Ensure we are working with integers
#     unvisited = unvisited_nodes.astype(int)
#
#     w = 0.6  # weight for dist from current to candidate
#     d_from_current = distance_matrix[current_node, unvisited]
#     d_to_destination = distance_matrix[unvisited, destination_node]
#     score = w * d_from_current + (1.0 - w) * d_to_destination
#
#     next_index = int(np.argmin(score))
#     return int(unvisited[next_index])
# ------------------------------------------------------
# Score        : -7.6266697669819
# Sample time  : 13.31727933883667
# Evaluate time: 0.026843786239624023
# Sample orders: 12
# ------------------------------------------------------
# Current best score: -7.6266697669819
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#
#     best_candidate = None
#     best_cost = float('inf')
#
#     for cand in unvisited:
#         cand = int(cand)
#         remaining = unvisited[unvisited != cand]
#
#         if remaining.size == 0:
#             # Only this candidate remains; go directly to destination after cand
#             cost = distance_matrix[current_node, cand] + distance_matrix[cand, destination_node]
#         else:
#             # Two-step lookahead: after cand, choose the best next (nxt) among remaining
#             # to minimize dist(cand, nxt) + dist(nxt, destination)
#             cand_to_others = distance_matrix[cand, remaining]
#             nxt_to_dest = distance_matrix[remaining, destination_node]
#             min_next_cost = float(np.min(cand_to_others + nxt_to_dest))
#             cost = distance_matrix[current_node, cand] + min_next_cost
#
#         if cost < best_cost:
#             best_cost = cost
#             best_candidate = cand
#
#     return int(best_candidate)
# ------------------------------------------------------
# Score        : -8.122970304138011
# Sample time  : 27.551740884780884
# Evaluate time: 0.0927591323852539
# Sample orders: 13
# ------------------------------------------------------
# Current best score: -7.6266697669819
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#     rng = np.random.default_rng(0)  # deterministic for reproducibility
#
#     best_candidate = None
#     best_avg_total = float('inf')
#     num_rollouts = 10  # number of random playouts per candidate
#
#     for cand in unvisited:
#         cand = int(cand)
#         remaining = unvisited[unvisited != cand]
#
#         if remaining.size == 0:
#             # Only this candidate remains
#             total_dist = distance_matrix[current_node, cand] + distance_matrix[cand, destination_node]
#             avg_dist = total_dist
#         else:
#             total_dist_sum = 0.0
#             for _ in range(num_rollouts):
#                 dist = distance_matrix[current_node, cand]
#                 cur = cand
#                 rem = remaining.copy()
#                 while rem.size > 0:
#                     # Bias the next-step choice towards closer nodes
#                     dists = distance_matrix[cur, rem.astype(int)]
#                     weights = 1.0 / (1.0 + dists)
#                     total_w = weights.sum()
#                     if total_w <= 0:
#                         probs = np.ones(rem.shape) / rem.size
#                     else:
#                         probs = weights / total_w
#                     nxt = int(rng.choice(rem, p=probs))
#                     dist += distance_matrix[cur, nxt]
#                     cur = nxt
#                     rem = rem[rem != nxt]
#                 dist += distance_matrix[cur, destination_node]
#                 total_dist_sum += dist
#             avg_dist = total_dist_sum / float(num_rollouts)
#
#         if avg_dist < best_avg_total:
#             best_avg_total = avg_dist
#             best_candidate = cand
#
#     return int(best_candidate)
# ------------------------------------------------------
# Score        : None
# Sample time  : 23.356333017349243
# Evaluate time: 20.01054883003235
# Sample orders: 14
# ------------------------------------------------------
# Current best score: -7.6266697669819
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#     rng = np.random.default_rng(0)  # deterministic for reproducibility
#
#     best_candidate = None
#     best_avg_total = float('inf')
#     num_rollouts = 5  # number of rollout completions to average
#     randomness_prob = 0.1  # probability to take a random tie-breaking choice
#
#     for cand in unvisited:
#         cand = int(cand)
#         remaining = unvisited[unvisited != cand]
#
#         if remaining.size == 0:
#             # Only this candidate remains
#             total_dist = distance_matrix[current_node, cand] + distance_matrix[cand, destination_node]
#             avg_dist = total_dist
#         else:
#             total_dist_sum = 0.0
#             for _ in range(num_rollouts):
#                 cur = cand
#                 dist = distance_matrix[current_node, cand]
#                 rem = remaining.copy()
#                 # Greedy completion: at each step, go to the nearest node in rem
#                 while rem.size > 0:
#                     rem_int = rem.astype(int)
#                     dists = distance_matrix[cur, rem_int]
#                     min_dist = dists.min()
#                     min_indices = np.where(dists == min_dist)[0]
#                     if min_indices.size > 0:
#                         if rng.random() < randomness_prob:
#                             choice_idx = rng.integers(0, min_indices.size)
#                         else:
#                             choice_idx = 0
#                         next_node = int(rem_int[min_indices[choice_idx]])
#                     else:
#                         next_node = int(rem_int[0])
#                     dist += distance_matrix[cur, next_node]
#                     cur = next_node
#                     rem = rem[rem != next_node]
#                 dist += distance_matrix[cur, destination_node]
#                 total_dist_sum += dist
#             avg_dist = total_dist_sum / float(num_rollouts)
#
#         if avg_dist < best_avg_total:
#             best_avg_total = avg_dist
#             best_candidate = cand
#
#     return int(best_candidate)
# ------------------------------------------------------
# Score        : -6.261641814060255
# Sample time  : 23.473631858825684
# Evaluate time: 8.178106307983398
# Sample orders: 15
# ------------------------------------------------------
# Current best score: -6.261641814060255
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#
#     best_candidate = None
#     best_score = float('inf')
#     weight = 1.0  # weight for the centrality term
#
#     for cand in unvisited:
#         cand = int(cand)
#         remaining = unvisited[unvisited != cand]
#
#         dist_to_cand = distance_matrix[current_node, cand]
#
#         if remaining.size == 0:
#             score = dist_to_cand
#         else:
#             sum_to_remaining = float(np.sum(distance_matrix[cand, remaining]))
#             score = dist_to_cand + weight * sum_to_remaining
#
#         if score < best_score:
#             best_score = score
#             best_candidate = cand
#
#     return int(best_candidate)
# ------------------------------------------------------
# Score        : -21.28957607329885
# Sample time  : 29.73709797859192
# Evaluate time: 0.08040499687194824
# Sample orders: 16
# ------------------------------------------------------
# Current best score: -6.261641814060255
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#     best_candidate = None
#     best_avg = float('inf')
#     depth_limit = 3
#     n_playouts = 6
#
#     rng = np.random.default_rng(0)
#
#     for cand in unvisited:
#         cand = int(cand)
#         remaining = unvisited[unvisited != cand]
#
#         dist_to_cand = distance_matrix[current_node, cand]
#
#         if remaining.size == 0:
#             total_est = dist_to_cand + distance_matrix[cand, destination_node]
#             avg_est = total_est
#         else:
#             total_acc = 0.0
#             for _ in range(n_playouts):
#                 dist = dist_to_cand
#                 cur = cand
#                 rem = remaining.copy()
#                 steps = min(depth_limit, rem.size)
#                 for __ in range(steps):
#                     dists = distance_matrix[cur, rem]
#                     idx_sorted = np.argsort(dists)
#                     K = min(3, rem.size)
#                     if rng.random() < 0.5:
#                         chosen_pos = 0
#                     else:
#                         chosen_pos = rng.integers(0, K)
#                     chosen_index = int(idx_sorted[chosen_pos])
#                     nxt = int(rem[chosen_index])
#                     dist += distance_matrix[cur, nxt]
#                     cur = nxt
#                     rem = rem[np.delete(np.arange(rem.size), chosen_index)]
#                     if rem.size == 0:
#                         break
#                 dist += distance_matrix[cur, destination_node]
#                 total_acc += dist
#             avg_est = total_acc / n_playouts
#
#         if avg_est < best_avg:
#             best_avg = avg_est
#             best_candidate = cand
#
#     return int(best_candidate)
# ------------------------------------------------------
# Score        : -8.554884336890865
# Sample time  : 29.196765899658203
# Evaluate time: 1.2720019817352295
# Sample orders: 17
# ------------------------------------------------------
# Current best score: -6.261641814060255
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#
#     # New scoring parameters for a different lookahead behavior
#     ALPHA = 0.7  # weight for the linear two-step cost
#     BETA = 0.3   # weight for the squared two-step cost
#
#     best_candidate = None
#     best_cost = float('inf')
#
#     for cand in unvisited:
#         cand = int(cand)
#         remaining = unvisited[unvisited != cand]
#
#         if remaining.size == 0:
#             # Only this candidate remains; go directly to destination after cand
#             cost = distance_matrix[current_node, cand] + distance_matrix[cand, destination_node]
#         else:
#             # Two-step lookahead with alternative scoring:
#             # linearly combine cand->nxt + nxt->dest, and also use squared version for diversity
#             cand_to_others = distance_matrix[cand, remaining]
#             nxt_to_dest = distance_matrix[remaining, destination_node]
#
#             min_next_cost_linear = float(np.min(cand_to_others + nxt_to_dest))
#             min_next_cost_sq = float(np.min(cand_to_others**2 + nxt_to_dest**2))
#
#             cost = distance_matrix[current_node, cand] + ALPHA * min_next_cost_linear + BETA * min_next_cost_sq
#
#         if cost < best_cost:
#             best_cost = cost
#             best_candidate = cand
#
#     return int(best_candidate)
# ------------------------------------------------------
# Score        : -8.077879786020546
# Sample time  : 26.28971004486084
# Evaluate time: 0.12225532531738281
# Sample orders: 18
# ------------------------------------------------------
# Current best score: -6.261641814060255
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     unvisited = unvisited_nodes.astype(int)
#
#     d_from_current = distance_matrix[current_node, unvisited]
#     next_index = int(np.argmin(d_from_current))
#     return int(unvisited[next_index])
# ------------------------------------------------------
# Score        : -6.8239686184057184
# Sample time  : 15.14200234413147
# Evaluate time: 0.03995084762573242
# Sample orders: 19
# ------------------------------------------------------
# Current best score: -6.261641814060255
# ======================================================
#
# ================= Evaluated Function =================
# def select_next_node(current_node: int, destination_node: int, unvisited_nodes: np.ndarray, distance_matrix: np.ndarray) -> int:
#     """Design an algorithm to select the next node in each step.
#     Args:
#         current_node    : ID of the current node.
#         destination_node: ID of the destination node.
#         unvisited_nodes : Array of IDs of unvisited nodes.
#         distance_matrix : Distance matrix of nodes.
#     Return:
#         ID of the next node to visit.
#     """
#     if unvisited_nodes.size == 0:
#         return int(destination_node)
#
#     # Ensure we are working with integers
#     unvisited = unvisited_nodes.astype(int)
#
#     # Compute additive distance score for each candidate (current -> candidate) + (candidate -> destination)
#     d_from_current = distance_matrix[current_node, unvisited]
#     d_to_destination = distance_matrix[unvisited, destination_node]
#     scores = d_from_current + d_to_destination
#
#     # Softmax probabilities over the negative scores (higher score -> lower probability)
#     temperature = 1.0  # can be tuned for exploration/exploitation
#     logits = -scores / temperature
#     max_logit = np.max(logits)
#     exp_logits = np.exp(logits - max_logit)  # numerical stability
#     probabilities = exp_logits / np.sum(exp_logits)
#
#     next_index = int(np.random.choice(len(unvisited), p=probabilities))
#     return int(unvisited[next_index])
# ------------------------------------------------------
# Score        : -23.811994699367325
# Sample time  : 25.645950078964233
# Evaluate time: 0.047719717025756836
# Sample orders: 20
# ------------------------------------------------------
# Current best score: -6.261641814060255
# ======================================================

# %%
# !tensorboard --logdir TSP
